# %%
import pandas as pd
import joblib

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/USER/Desktop/URL-Phishing-Detection/datasets/2_test_dataset.csv')

# %%
df = df.drop("url", axis=1)

# %%
X_test = df.drop("Label", axis=1)
y_test = df["Label"]

# %%
print(X_test.columns)
# Out:
# Index(['LengthOfURL', 'DomainLengthOfURL', 'TLDLength', 'IsDomainIP',
#        'DigitCntInURL', 'EqualCharCntInURL', 'QuesMarkCntInURL',
#        'OtherSpclCharCntInURL', 'URLLetterRatio', 'HavingPath', 'HavingAnchor',
#        'PathLength', 'ShannonEntropy', 'FractalDimension',
#        'KolmogorovComplexity', 'HexPatternCnt', 'Base64PatternCnt'],
#       dtype='object')

# %%
model_names = [
    "BernoulliNB",
    "LogisticRegression",
    "DecisionTreeClassifier",
    "RandomForestClassifier",
    "GradientBoostingClassifier",
    "KNeighborsClassifier",
    "AdaBoostClassifier",
]

models = {}
for name in model_names:
    models[name] = joblib.load(f"models/{name}.pkl")

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

results = []

for name, model in models.items():

    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append([name, acc, prec, rec, f1])

    print(f"\n{name}")
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "Precision", "Recall", "F1"])
results_df.sort_values("F1", ascending=False)
# Out:
# BernoulliNB
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#
# LogisticRegression
# Confusion Matrix:
# [[187803 157935]
#  [ 96795  61883]]
#
# DecisionTreeClassifier
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#
# RandomForestClassifier
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#
# GradientBoostingClassifier
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#
# KNeighborsClassifier
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#
# AdaBoostClassifier
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#                         Model  Accuracy  Precision    Recall        F1
# 0                 BernoulliNB  0.314578   0.314578  1.000000  0.478599
# 2      DecisionTreeClassifier  0.314578   0.314578  1.000000  0.478599
# 3      RandomForestClassifier  0.314578   0.314578  1.000000  0.478599
# 5        KNeighborsClassifier  0.314578   0.314578  1.000000  0.478599
# 4  GradientBoostingClassifier  0.314578   0.314578  1.000000  0.478599
# 6          AdaBoostClassifier  0.314578   0.314578  1.000000  0.478599
# 1          LogisticRegression  0.495000   0.281519  0.389991  0.326994

# %%
df.dtypes
# Out:
# Label                      int64
# LengthOfURL                int64
# DomainLengthOfURL          int64
# TLDLength                  int64
# IsDomainIP                 int64
# DigitCntInURL              int64
# EqualCharCntInURL          int64
# QuesMarkCntInURL           int64
# OtherSpclCharCntInURL      int64
# URLLetterRatio           float64
# HavingPath                 int64
# HavingAnchor               int64
# PathLength                 int64
# ShannonEntropy           float64
# FractalDimension         float64
# KolmogorovComplexity     float64
# HexPatternCnt              int64
# Base64PatternCnt           int64
# dtype: object

# %%
print("TRAIN STATS")
print(df.describe())
# Out:
# TRAIN STATS
#                Label    LengthOfURL  DomainLengthOfURL      TLDLength  \
# count  504416.000000  504416.000000      504416.000000  504416.000000
# mean        0.314578      60.943192          20.030288       2.901080
# std         0.464348      66.329462           8.640023       0.518361
# min         0.000000       8.000000           0.000000       0.000000
# 25%         0.000000      39.000000          15.000000       3.000000
# 50%         0.000000      52.000000          19.000000       3.000000
# 75%         1.000000      72.000000          23.000000       3.000000
# max         1.000000   25523.000000         240.000000     121.000000
#
#           IsDomainIP  DigitCntInURL  EqualCharCntInURL  QuesMarkCntInURL  \
# count  504416.000000  504416.000000      504416.000000     504416.000000
# mean        0.008739       4.523917           0.270081          0.150356
# std         0.093072      11.977236           1.067765          0.454429
# min         0.000000       0.000000           0.000000          0.000000
# 25%         0.000000       0.000000           0.000000          0.000000
# 50%         0.000000       1.000000           0.000000          0.000000
# 75%         0.000000       6.000000           0.000000          0.000000
# max         1.000000    3413.000000         131.000000        166.000000
#
#        OtherSpclCharCntInURL  URLLetterRatio     HavingPath   HavingAnchor  \
# count          504416.000000   504416.000000  504416.000000  504416.000000
# mean                9.980653        0.759403       0.829551       0.002080
# std                 5.436726        0.085188       0.376027       0.045556
# min                 3.000000        0.104603       0.000000       0.000000
# 25%                 7.000000        0.725000       1.000000       0.000000
# 50%                 9.000000        0.782258       1.000000       0.000000
# 75%                11.000000        0.816327       1.000000       0.000000
# max               579.000000        0.986431       1.000000       1.000000
#
#           PathLength  ShannonEntropy  FractalDimension  KolmogorovComplexity  \
# count  504416.000000   504416.000000     504416.000000         504416.000000
# mean       26.947476        4.322901          1.091904              1.111190
# std        27.468767        0.352123          0.075768              0.131483
# min         0.000000        1.339504          0.246033              0.164313
# 25%         9.000000        4.098394          1.044307              1.028169
# 50%        21.000000        4.296631          1.091576              1.125000
# 75%        38.000000        4.531842          1.142396              1.200000
# max      3212.000000        6.048781          1.375933              2.000000
#
#        HexPatternCnt  Base64PatternCnt
# count  504416.000000     504416.000000
# mean        0.088845          0.415437
# std         1.167623          0.630369
# min         0.000000          0.000000
# 25%         0.000000          0.000000
# 50%         0.000000          0.000000
# 75%         0.000000          1.000000
# max       134.000000         32.000000
