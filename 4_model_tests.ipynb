# %%
import pandas as pd
import joblib

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/mmeliht/Desktop/URL-Phishing-Detection/datasets/2_test_dataset.csv')

# %%
df = df.drop("url", axis=1)

# %%
X_test = df.drop("Label", axis=1)
y_test = df["Label"]

# %%
print(X_test.columns)
# Out:
# Index(['LengthOfURL', 'DomainLengthOfURL', 'TLDLength', 'IsDomainIP',
#        'DigitCntInURL', 'EqualCharCntInURL', 'QuesMarkCntInURL',
#        'OtherSpclCharCntInURL', 'URLLetterRatio', 'HavingPath', 'HavingAnchor',
#        'PathLength', 'ShannonEntropy', 'FractalDimension',
#        'KolmogorovComplexity', 'HexPatternCnt', 'Base64PatternCnt'],
#       dtype='object')

# %%
model_names = [
    "BernoulliNB",
    "LogisticRegression",
    "DecisionTreeClassifier",
    "RandomForestClassifier",
    "GradientBoostingClassifier",
    "KNeighborsClassifier",
    "AdaBoostClassifier",
    "MultinomialNB"
]

models = {}
for name in model_names:
    models[name] = joblib.load(f"models/{name}.pkl")

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

results = []

for name, model in models.items():

    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append([name, acc, prec, rec, f1])

    print(f"\n{name}")
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "Precision", "Recall", "F1"])
results_df.sort_values("F1", ascending=False)
# Out:
# BernoulliNB
# Confusion Matrix:
# [[  2500 343238]
#  [  7599 151079]]
#
# LogisticRegression
# Confusion Matrix:
# [[     5 345733]
#  [    61 158617]]
#
# DecisionTreeClassifier
# Confusion Matrix:
# [[     0 345738]
#  [    12 158666]]
#
# RandomForestClassifier
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#
# GradientBoostingClassifier
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#
# KNeighborsClassifier
# Confusion Matrix:
# [[    59 345679]
#  [   279 158399]]
#
# AdaBoostClassifier
# Confusion Matrix:
# [[     0 345738]
#  [     0 158678]]
#
# MultinomialNB
# Confusion Matrix:
# [[ 46368 299370]
#  [ 23700 134978]]
#                         Model  Accuracy  Precision    Recall        F1
# 3      RandomForestClassifier  0.314578   0.314578  1.000000  0.478599
# 4  GradientBoostingClassifier  0.314578   0.314578  1.000000  0.478599
# 6          AdaBoostClassifier  0.314578   0.314578  1.000000  0.478599
# 2      DecisionTreeClassifier  0.314554   0.314561  0.999924  0.478571
# 1          LogisticRegression  0.314467   0.314498  0.999616  0.478462
# 5        KNeighborsClassifier  0.314142   0.314235  0.998242  0.478001
# 0                 BernoulliNB  0.304469   0.305632  0.952111  0.462726
# 7               MultinomialNB  0.359517   0.310760  0.850641  0.455218

# %%
df["Label"].value_counts()
# Out:
# Label
# 0    345738
# 1    158678
# Name: count, dtype: int64

# %%
models["RandomForestClassifier"].feature_names_in_
# Out:
# array(['LengthOfURL', 'DomainLengthOfURL', 'TLDLength', 'IsDomainIP',
#        'DigitCntInURL', 'EqualCharCntInURL', 'QuesMarkCntInURL',
#        'OtherSpclCharCntInURL', 'URLLetterRatio', 'HavingPath',
#        'HavingAnchor', 'PathLength', 'ShannonEntropy', 'FractalDimension',
#        'KolmogorovComplexity', 'HexPatternCnt', 'Base64PatternCnt'],
#       dtype=object)

# %%
X_test.columns
# Out:
# Index(['LengthOfURL', 'DomainLengthOfURL', 'TLDLength', 'IsDomainIP',
#        'DigitCntInURL', 'EqualCharCntInURL', 'QuesMarkCntInURL',
#        'OtherSpclCharCntInURL', 'URLLetterRatio', 'HavingPath', 'HavingAnchor',
#        'PathLength', 'ShannonEntropy', 'FractalDimension',
#        'KolmogorovComplexity', 'HexPatternCnt', 'Base64PatternCnt'],
#       dtype='object')
