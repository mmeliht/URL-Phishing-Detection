# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/USER/Desktop/URL-Phishing-Detection/datasets/clean_data_train.csv")

# %%
df.head(10)
# Out:
#    LengthOfURL  DomainLengthOfURL  IsDomainIP  TLDLength  URLLetterRatio  \
# 0           84                 76           0          3           0.655
# 1           40                 20           1          8           0.250
# 2           28                 19           0          3           0.536
# 3           31                 23           0          3           0.677
# 4           23                 15           0          2           0.391
# 5           34                 25           0          3           0.647
# 6           38                 30           0          3           0.579
# 7           28                 20           0          2           0.536
# 8           22                  7           0          2           0.500
# 9           26                 18           0          3           0.500
#
#    DigitCntInURL  EqualCharCntInURL  QuesMarkCntInURL  OtherSpclCharCntInURL  \
# 0             17                  0                 0                      4
# ...
